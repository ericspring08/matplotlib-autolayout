# %%
import sys
sys.path.append('..')
from src.flexboxify import flexboxify
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(10, 20))

fig.add_subplot(title='subplot 1').plot([1, 2, 3], [1, 2, 3])
fig.add_subplot(title='subplot 2').plot([1, 2, 3], [3, 2, 1])
fig.add_subplot(title='subplot 3').plot([1, 2, 3], [1, 1, 1])

flexbox_config = {
    'flex-direction': 'column',
    'margin': 0.02,
}

flexboxify(fig, flexbox_config=flexbox_config)

fig.show()
# Out:
# /var/folders/t9/tlymbrbn2874888599gmyxdh0000gn/T/ipykernel_36380/2320751424.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
