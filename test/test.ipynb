# %%
import sys
sys.path.append('..')
from matplotlib_autolayout.autolayout import autolayout
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
# font size
plt.rcParams.update({'font.size': 30})

for i in range(10):
    fig.add_subplot(title=f"Subplot {str(i)}").plot([1, 2, 3], [1, 2, 3])

autolayout(fig, configuration="direction-row count-2 margin-0.2")

fig.show()
# Out:
# {'direction': 'row', 'count': 2, 'margin': 0.2}
# /var/folders/t9/tlymbrbn2874888599gmyxdh0000gn/T/ipykernel_58800/3475980328.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
