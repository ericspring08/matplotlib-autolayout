# %%
import sys
sys.path.append('..')
from basic import flexboxify
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(10, 5))

fig.add_subplot(title='subplot 1')
fig.add_subplot(title='subplot 2')

flexbox_config = {
    'configuration': {
        'flex-direction': 'row',
        'margin': 0.1,
        'justify-content': 'center',
        'align-items': 'center'
    },
}

flexboxify(fig, flexbox_config=flexbox_config)

fig.show()
# Out:
# 0.1
# /var/folders/t9/tlymbrbn2874888599gmyxdh0000gn/T/ipykernel_30778/574728429.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
